# %% [markdown]
# # NASA Space Apps Challenge 2025 - A World Away: Hunting for Exoplanets with AI

# %% [markdown]
# ## Data Loading and Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Initial Structure Analysis

# %%
import pandas as pd

# %%
df = pd.read_csv("./data/cumulative_2025.10.04_06.31.08.csv", comment="#")
df
# Out:
#       loc_rowid     kepid kepoi_name   kepler_name koi_disposition  \
# 0             1  10797460  K00752.01  Kepler-227 b       CONFIRMED
# 1             2  10797460  K00752.02  Kepler-227 c       CONFIRMED
# 2             3  10811496  K00753.01           NaN       CANDIDATE
# 3             4  10848459  K00754.01           NaN  FALSE POSITIVE
# 4             5  10854555  K00755.01  Kepler-664 b       CONFIRMED
# ...         ...       ...        ...           ...             ...
# 9559       9560  10090151  K07985.01           NaN  FALSE POSITIVE
# 9560       9561  10128825  K07986.01           NaN       CANDIDATE
# 9561       9562  10147276  K07987.01           NaN  FALSE POSITIVE
# 9562       9563  10155286  K07988.01           NaN       CANDIDATE
# 9563       9564  10156110  K07989.01           NaN  FALSE POSITIVE
#
#      koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0           CANDIDATE      1.000              0              0              0
# 1           CANDIDATE      0.969              0              0              0
# 2           CANDIDATE      0.000              0              0              0
# 3      FALSE POSITIVE      0.000              0              1              0
# 4           CANDIDATE      1.000              0              0              0
# ...               ...        ...            ...            ...            ...
# 9559   FALSE POSITIVE      0.000              0              1              1
# 9560        CANDIDATE      0.497              0              0              0
# 9561   FALSE POSITIVE      0.021              0              0              1
# 9562        CANDIDATE      0.092              0              0              0
# 9563   FALSE POSITIVE      0.000              0              0              1
#
#       ...  koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  \
# 0     ...           -81.0      4.467           0.064          -0.096
# 1     ...           -81.0      4.467           0.064          -0.096
# 2     ...          -176.0      4.544           0.044          -0.176
# 3     ...          -174.0      4.564           0.053          -0.168
# 4     ...          -211.0      4.438           0.070          -0.210
# ...   ...             ...        ...             ...             ...
# 9559  ...          -166.0      4.529           0.035          -0.196
# 9560  ...          -220.0      4.444           0.056          -0.224
# 9561  ...          -236.0      4.447           0.056          -0.224
# 9562  ...          -128.0      2.992           0.030          -0.027
# 9563  ...          -225.0      4.385           0.054          -0.216
#
#       koi_srad  koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag
# 0        0.927          0.105         -0.061  291.93423  48.141651      15.347
# 1        0.927          0.105         -0.061  291.93423  48.141651      15.347
# 2        0.868          0.233         -0.078  297.00482  48.134129      15.436
# 3        0.791          0.201         -0.067  285.53461  48.285210      15.597
# 4        1.046          0.334         -0.133  288.75488  48.226200      15.509
# ...        ...            ...            ...        ...        ...         ...
# 9559     0.903          0.237         -0.079  297.18875  47.093819      14.082
# 9560     1.031          0.341         -0.114  286.50937  47.163219      14.757
# 9561     1.041          0.341         -0.114  294.16489  47.176281      15.385
# 9562     7.824          0.223         -1.896  296.76288  47.145142      10.998
# 9563     1.193          0.410         -0.137  297.00977  47.121021      14.826
#
# [9564 rows x 50 columns]

# %%
df.shape
# Out:
# (9564, 50)

# %%
df.head()
# Out:
#    loc_rowid     kepid kepoi_name   kepler_name koi_disposition  \
# 0          1  10797460  K00752.01  Kepler-227 b       CONFIRMED
# 1          2  10797460  K00752.02  Kepler-227 c       CONFIRMED
# 2          3  10811496  K00753.01           NaN       CANDIDATE
# 3          4  10848459  K00754.01           NaN  FALSE POSITIVE
# 4          5  10854555  K00755.01  Kepler-664 b       CONFIRMED
#
#   koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0        CANDIDATE      1.000              0              0              0
# 1        CANDIDATE      0.969              0              0              0
# 2        CANDIDATE      0.000              0              0              0
# 3   FALSE POSITIVE      0.000              0              1              0
# 4        CANDIDATE      1.000              0              0              0
#
#    ...  koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# 0  ...           -81.0      4.467           0.064          -0.096     0.927
# 1  ...           -81.0      4.467           0.064          -0.096     0.927
# 2  ...          -176.0      4.544           0.044          -0.176     0.868
# 3  ...          -174.0      4.564           0.053          -0.168     0.791
# 4  ...          -211.0      4.438           0.070          -0.210     1.046
#
#    koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag
# 0          0.105         -0.061  291.93423  48.141651      15.347
# 1          0.105         -0.061  291.93423  48.141651      15.347
# 2          0.233         -0.078  297.00482  48.134129      15.436
# 3          0.201         -0.067  285.53461  48.285210      15.597
# 4          0.334         -0.133  288.75488  48.226200      15.509
#
# [5 rows x 50 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 50 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   loc_rowid          9564 non-null   int64
#  1   kepid              9564 non-null   int64
#  2   kepoi_name         9564 non-null   object
#  3   kepler_name        2747 non-null   object
#  4   koi_disposition    9564 non-null   object
#  5   koi_pdisposition   9564 non-null   object
#  6   koi_score          8054 non-null   float64
#  7   koi_fpflag_nt      9564 non-null   int64
#  8   koi_fpflag_ss      9564 non-null   int64
#  9   koi_fpflag_co      9564 non-null   int64
#  10  koi_fpflag_ec      9564 non-null   int64
#  11  koi_period         9564 non-null   float64
#  12  koi_period_err1    9110 non-null   float64
#  13  koi_period_err2    9110 non-null   float64
#  14  koi_time0bk        9564 non-null   float64
#  15  koi_time0bk_err1   9110 non-null   float64
#  16  koi_time0bk_err2   9110 non-null   float64
#  17  koi_impact         9201 non-null   float64
#  18  koi_impact_err1    9110 non-null   float64
#  19  koi_impact_err2    9110 non-null   float64
#  20  koi_duration       9564 non-null   float64
#  21  koi_duration_err1  9110 non-null   float64
#  22  koi_duration_err2  9110 non-null   float64
#  23  koi_depth          9201 non-null   float64
#  24  koi_depth_err1     9110 non-null   float64
#  25  koi_depth_err2     9110 non-null   float64
#  26  koi_prad           9201 non-null   float64
#  27  koi_prad_err1      9201 non-null   float64
#  28  koi_prad_err2      9201 non-null   float64
#  29  koi_teq            9201 non-null   float64
#  30  koi_teq_err1       0 non-null      float64
#  31  koi_teq_err2       0 non-null      float64
#  32  koi_insol          9243 non-null   float64
#  33  koi_insol_err1     9243 non-null   float64
#  34  koi_insol_err2     9243 non-null   float64
#  35  koi_model_snr      9201 non-null   float64
#  36  koi_tce_plnt_num   9218 non-null   float64
#  37  koi_tce_delivname  9218 non-null   object
#  38  koi_steff          9201 non-null   float64
#  39  koi_steff_err1     9096 non-null   float64
#  40  koi_steff_err2     9081 non-null   float64
#  41  koi_slogg          9201 non-null   float64
#  42  koi_slogg_err1     9096 non-null   float64
#  43  koi_slogg_err2     9096 non-null   float64
#  44  koi_srad           9201 non-null   float64
#  45  koi_srad_err1      9096 non-null   float64
#  46  koi_srad_err2      9096 non-null   float64
#  47  ra                 9564 non-null   float64
#  48  dec                9564 non-null   float64
#  49  koi_kepmag         9563 non-null   float64
# dtypes: float64(39), int64(6), object(5)
# memory usage: 3.6+ MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#          loc_rowid         kepid    koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# count  9564.000000  9.564000e+03  8054.000000    9564.000000    9564.000000
# mean   4782.500000  7.690628e+06     0.480829       0.208595       0.232748
# std    2761.033321  2.653459e+06     0.476928       4.767290       0.422605
# min       1.000000  7.574500e+05     0.000000       0.000000       0.000000
# 25%    2391.750000  5.556034e+06     0.000000       0.000000       0.000000
# 50%    4782.500000  7.906892e+06     0.334000       0.000000       0.000000
# 75%    7173.250000  9.873066e+06     0.998000       0.000000       0.000000
# max    9564.000000  1.293514e+07     1.000000     465.000000       1.000000
#
#        koi_fpflag_co  koi_fpflag_ec     koi_period  koi_period_err1  \
# count    9564.000000    9564.000000    9564.000000      9110.000000
# mean        0.197512       0.120033      75.671358         0.002148
# std         0.398142       0.325018    1334.744046         0.008236
# min         0.000000       0.000000       0.241843         0.000000
# 25%         0.000000       0.000000       2.733684         0.000005
# 50%         0.000000       0.000000       9.752831         0.000035
# 75%         0.000000       0.000000      40.715178         0.000276
# max         1.000000       1.000000  129995.778400         0.172500
#
#        koi_period_err2  ...  koi_steff_err2    koi_slogg  koi_slogg_err1  \
# count      9110.000000  ...     9081.000000  9201.000000     9096.000000
# mean         -0.002148  ...     -162.265059     4.310157        0.120738
# std           0.008236  ...       72.746348     0.432606        0.132837
# min          -0.172500  ...    -1762.000000     0.047000        0.000000
# 25%          -0.000276  ...     -198.000000     4.218000        0.042000
# 50%          -0.000035  ...     -160.000000     4.438000        0.070000
# 75%          -0.000005  ...     -114.000000     4.543000        0.149000
# max           0.000000  ...        0.000000     5.364000        1.472000
#
#        koi_slogg_err2     koi_srad  koi_srad_err1  koi_srad_err2           ra  \
# count     9096.000000  9201.000000    9096.000000    9096.000000  9564.000000
# mean        -0.143161     1.728712       0.362292      -0.394806   292.060163
# std          0.085477     6.127185       0.930870       2.168213     4.766657
# min         -1.207000     0.109000       0.000000    -116.137000   279.852720
# 25%         -0.196000     0.829000       0.129000      -0.250000   288.660770
# 50%         -0.128000     1.000000       0.251000      -0.111000   292.261125
# 75%         -0.088000     1.345000       0.364000      -0.069000   295.859160
# max          0.000000   229.908000      33.091000       0.000000   301.720760
#
#                dec   koi_kepmag
# count  9564.000000  9563.000000
# mean     43.810433    14.264606
# std       3.601243     1.385448
# min      36.577381     6.966000
# 25%      40.777173    13.440000
# 50%      43.677504    14.520000
# 75%      46.714611    15.322000
# max      52.336010    20.003000
#
# [8 rows x 45 columns]

# %%
df.isnull().sum()
# Out:
# loc_rowid               0
# kepid                   0
# kepoi_name              0
# kepler_name          6817
# koi_disposition         0
# koi_pdisposition        0
# koi_score            1510
# koi_fpflag_nt           0
# koi_fpflag_ss           0
# koi_fpflag_co           0
# koi_fpflag_ec           0
# koi_period              0
# koi_period_err1       454
# koi_period_err2       454
# koi_time0bk             0
# koi_time0bk_err1      454
# koi_time0bk_err2      454
# koi_impact            363
# koi_impact_err1       454
# koi_impact_err2       454
# koi_duration            0
# koi_duration_err1     454
# koi_duration_err2     454
# koi_depth             363
# koi_depth_err1        454
# koi_depth_err2        454
# koi_prad              363
# koi_prad_err1         363
# koi_prad_err2         363
# koi_teq               363
# koi_teq_err1         9564
# koi_teq_err2         9564
# koi_insol             321
# koi_insol_err1        321
# koi_insol_err2        321
# koi_model_snr         363
# koi_tce_plnt_num      346
# koi_tce_delivname     346
# koi_steff             363
# koi_steff_err1        468
# koi_steff_err2        483
# koi_slogg             363
# koi_slogg_err1        468
# koi_slogg_err2        468
# koi_srad              363
# koi_srad_err1         468
# koi_srad_err2         468
# ra                      0
# dec                     0
# koi_kepmag              1
# dtype: int64

# %% [markdown]
# koi_teq_err1 and koi_teq_err2 are empty

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Initial Cleaning and Column Removal

# %%
df = df.drop(columns=["koi_teq_err1", "koi_teq_err2"])
df
# Out:
#       loc_rowid     kepid kepoi_name   kepler_name koi_disposition  \
# 0             1  10797460  K00752.01  Kepler-227 b       CONFIRMED
# 1             2  10797460  K00752.02  Kepler-227 c       CONFIRMED
# 2             3  10811496  K00753.01           NaN       CANDIDATE
# 3             4  10848459  K00754.01           NaN  FALSE POSITIVE
# 4             5  10854555  K00755.01  Kepler-664 b       CONFIRMED
# ...         ...       ...        ...           ...             ...
# 9559       9560  10090151  K07985.01           NaN  FALSE POSITIVE
# 9560       9561  10128825  K07986.01           NaN       CANDIDATE
# 9561       9562  10147276  K07987.01           NaN  FALSE POSITIVE
# 9562       9563  10155286  K07988.01           NaN       CANDIDATE
# 9563       9564  10156110  K07989.01           NaN  FALSE POSITIVE
#
#      koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0           CANDIDATE      1.000              0              0              0
# 1           CANDIDATE      0.969              0              0              0
# 2           CANDIDATE      0.000              0              0              0
# 3      FALSE POSITIVE      0.000              0              1              0
# 4           CANDIDATE      1.000              0              0              0
# ...               ...        ...            ...            ...            ...
# 9559   FALSE POSITIVE      0.000              0              1              1
# 9560        CANDIDATE      0.497              0              0              0
# 9561   FALSE POSITIVE      0.021              0              0              1
# 9562        CANDIDATE      0.092              0              0              0
# 9563   FALSE POSITIVE      0.000              0              0              1
#
#       ...  koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  \
# 0     ...           -81.0      4.467           0.064          -0.096
# 1     ...           -81.0      4.467           0.064          -0.096
# 2     ...          -176.0      4.544           0.044          -0.176
# 3     ...          -174.0      4.564           0.053          -0.168
# 4     ...          -211.0      4.438           0.070          -0.210
# ...   ...             ...        ...             ...             ...
# 9559  ...          -166.0      4.529           0.035          -0.196
# 9560  ...          -220.0      4.444           0.056          -0.224
# 9561  ...          -236.0      4.447           0.056          -0.224
# 9562  ...          -128.0      2.992           0.030          -0.027
# 9563  ...          -225.0      4.385           0.054          -0.216
#
#       koi_srad  koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag
# 0        0.927          0.105         -0.061  291.93423  48.141651      15.347
# 1        0.927          0.105         -0.061  291.93423  48.141651      15.347
# 2        0.868          0.233         -0.078  297.00482  48.134129      15.436
# 3        0.791          0.201         -0.067  285.53461  48.285210      15.597
# 4        1.046          0.334         -0.133  288.75488  48.226200      15.509
# ...        ...            ...            ...        ...        ...         ...
# 9559     0.903          0.237         -0.079  297.18875  47.093819      14.082
# 9560     1.031          0.341         -0.114  286.50937  47.163219      14.757
# 9561     1.041          0.341         -0.114  294.16489  47.176281      15.385
# 9562     7.824          0.223         -1.896  296.76288  47.145142      10.998
# 9563     1.193          0.410         -0.137  297.00977  47.121021      14.826
#
# [9564 rows x 48 columns]

# %% [markdown]
# These columns are not relevant for classification:
# - loc_rowid
# - kepid
# - kepoi_name
# - kepler_name
#
# These columns may cause data leakage:
# - koi_disposition
# - koi_score
# - koi_fpflag_nt
# - koi_fpflag_ss
# - koi_fpflag_co
# - koi_fpflag_ec

# %%
df = df.drop(columns=["loc_rowid", "kepid", "kepoi_name", "kepler_name", "koi_disposition", "koi_score", "koi_fpflag_nt", "koi_fpflag_ss", "koi_fpflag_co", "koi_fpflag_ec"])
df
# Out:
#      koi_pdisposition  koi_period  koi_period_err1  koi_period_err2  \
# 0           CANDIDATE    9.488036     2.775000e-05    -2.775000e-05
# 1           CANDIDATE   54.418383     2.479000e-04    -2.479000e-04
# 2           CANDIDATE   19.899140     1.494000e-05    -1.494000e-05
# 3      FALSE POSITIVE    1.736952     2.630000e-07    -2.630000e-07
# 4           CANDIDATE    2.525592     3.761000e-06    -3.761000e-06
# ...               ...         ...              ...              ...
# 9559   FALSE POSITIVE    0.527699     1.160000e-07    -1.160000e-07
# 9560        CANDIDATE    1.739849     1.780000e-05    -1.780000e-05
# 9561   FALSE POSITIVE    0.681402     2.434000e-06    -2.434000e-06
# 9562        CANDIDATE  333.486169     4.235000e-03    -4.235000e-03
# 9563   FALSE POSITIVE    4.856035     6.356000e-05    -6.356000e-05
#
#       koi_time0bk  koi_time0bk_err1  koi_time0bk_err2  koi_impact  \
# 0      170.538750          0.002160         -0.002160       0.146
# 1      162.513840          0.003520         -0.003520       0.586
# 2      175.850252          0.000581         -0.000581       0.969
# 3      170.307565          0.000115         -0.000115       1.276
# 4      171.595550          0.001130         -0.001130       0.701
# ...           ...               ...               ...         ...
# 9559   131.705093          0.000170         -0.000170       1.252
# 9560   133.001270          0.007690         -0.007690       0.043
# 9561   132.181750          0.002850         -0.002850       0.147
# 9562   153.615010          0.005070         -0.005070       0.214
# 9563   135.993300          0.010800         -0.010800       0.134
#
#       koi_impact_err1  koi_impact_err2  ...  koi_steff_err2  koi_slogg  \
# 0               0.318           -0.146  ...           -81.0      4.467
# 1               0.059           -0.443  ...           -81.0      4.467
# 2               5.126           -0.077  ...          -176.0      4.544
# 3               0.115           -0.092  ...          -174.0      4.564
# 4               0.235           -0.478  ...          -211.0      4.438
# ...               ...              ...  ...             ...        ...
# 9559            0.051           -0.049  ...          -166.0      4.529
# 9560            0.423           -0.043  ...          -220.0      4.444
# 9561            0.309           -0.147  ...          -236.0      4.447
# 9562            0.255           -0.214  ...          -128.0      2.992
# 9563            0.323           -0.134  ...          -225.0      4.385
#
#       koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2  \
# 0              0.064          -0.096     0.927          0.105         -0.061
# 1              0.064          -0.096     0.927          0.105         -0.061
# 2              0.044          -0.176     0.868          0.233         -0.078
# 3              0.053          -0.168     0.791          0.201         -0.067
# 4              0.070          -0.210     1.046          0.334         -0.133
# ...              ...             ...       ...            ...            ...
# 9559           0.035          -0.196     0.903          0.237         -0.079
# 9560           0.056          -0.224     1.031          0.341         -0.114
# 9561           0.056          -0.224     1.041          0.341         -0.114
# 9562           0.030          -0.027     7.824          0.223         -1.896
# 9563           0.054          -0.216     1.193          0.410         -0.137
#
#              ra        dec  koi_kepmag
# 0     291.93423  48.141651      15.347
# 1     291.93423  48.141651      15.347
# 2     297.00482  48.134129      15.436
# 3     285.53461  48.285210      15.597
# 4     288.75488  48.226200      15.509
# ...         ...        ...         ...
# 9559  297.18875  47.093819      14.082
# 9560  286.50937  47.163219      14.757
# 9561  294.16489  47.176281      15.385
# 9562  296.76288  47.145142      10.998
# 9563  297.00977  47.121021      14.826
#
# [9564 rows x 38 columns]

# %% [markdown]
# As categorical variables, both koi_disposition and koi_tce_delivname require transformation into numeric representations before model training.

# %%
df["koi_tce_delivname"].unique()
# Out:
# array(['q1_q17_dr25_tce', 'q1_q16_tce', nan, 'q1_q17_dr24_tce'],
#       dtype=object)

# %% [markdown]
# ### Train/Test Split

# %%
from sklearn.model_selection import train_test_split

X = df.drop("koi_pdisposition", axis=1)
y = df["koi_pdisposition"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# %% [markdown]
# ### Transformation and Encoding Pipeline

# %%
mapping = {"FALSE POSITIVE": 0, "CANDIDATE": 1}

y_train = y_train.map(mapping)
y_test = y_test.map(mapping)

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
import numpy as np

categorical_columns = ['koi_tce_delivname']
numerical_cols = [c for c in X_train.columns if c not in categorical_columns]


categorical_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_pipeline, categorical_columns),
        ('num', 'passthrough', numerical_cols)
    ]
)

X_train_transformed = preprocessor.fit_transform(X_train)
X_test_transformed = preprocessor.transform(X_test)

cat_columns = preprocessor.named_transformers_['cat']['onehot'].get_feature_names_out(categorical_columns)
all_columns = np.concatenate([cat_columns, numerical_cols])

X_train = pd.DataFrame(X_train_transformed, columns=all_columns, index=X_train.index)
X_test = pd.DataFrame(X_test_transformed, columns=all_columns, index=X_test.index)

# %%
X_train.head()
# Out:
#       koi_tce_delivname_q1_q16_tce  koi_tce_delivname_q1_q17_dr24_tce  \
# 6279                           1.0                                0.0
# 5470                           0.0                                0.0
# 7924                           0.0                                0.0
# 5098                           0.0                                0.0
# 731                            0.0                                0.0
#
#       koi_tce_delivname_q1_q17_dr25_tce  koi_period  koi_period_err1  \
# 6279                                0.0  163.104677     3.791000e-03
# 5470                                1.0   34.211502     3.004000e-04
# 7924                                1.0   21.142459     7.910000e-07
# 5098                                1.0   11.806174     1.518000e-04
# 731                                 1.0  251.059725     3.727000e-04
#
#       koi_period_err2  koi_time0bk  koi_time0bk_err1  koi_time0bk_err2  \
# 6279    -3.791000e-03   140.316300          0.023100         -0.023100
# 5470    -3.004000e-04   154.575080          0.007850         -0.007850
# 7924    -7.910000e-07   138.391633          0.000032         -0.000032
# 5098    -1.518000e-04   138.264100          0.010700         -0.010700
# 731     -3.727000e-04   230.027745          0.000934         -0.000934
#
#       koi_impact  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 6279       0.575  ...          -195.0      4.418           0.078
# 5470       0.034  ...          -100.0      4.610           0.018
# 7924       0.971  ...          -190.0      4.495           0.054
# 5098       0.905  ...          -204.0      3.843           0.259
# 731        1.264  ...          -114.0      4.340           0.120
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 6279          -0.279     1.040          0.434         -0.121  292.20850
# 5470          -0.046     0.721          0.047         -0.029  286.66296
# 7924          -0.229     0.945          0.304         -0.101  289.48297
# 5098          -0.111     2.599          0.523         -0.850  281.97125
# 731           -0.108     1.086          0.163         -0.147  290.20236
#
#             dec  koi_kepmag
# 6279  42.158611      15.201
# 5470  47.413700      14.017
# 7924  40.292751      14.083
# 5098  43.672771      12.082
# 731   42.955891      14.695
#
# [5 rows x 39 columns]

# %%
X_test.head()
# Out:
#       koi_tce_delivname_q1_q16_tce  koi_tce_delivname_q1_q17_dr24_tce  \
# 495                            0.0                                0.0
# 1419                           0.0                                0.0
# 9205                           0.0                                0.0
# 5517                           0.0                                0.0
# 8137                           0.0                                0.0
#
#       koi_tce_delivname_q1_q17_dr25_tce  koi_period  koi_period_err1  \
# 495                                 1.0    1.634846              NaN
# 1419                                1.0   12.439294     5.267000e-05
# 9205                                1.0  333.716340              NaN
# 5517                                1.0  219.321556     8.517000e-04
# 8137                                1.0    0.609662     2.200000e-08
#
#       koi_period_err2  koi_time0bk  koi_time0bk_err1  koi_time0bk_err2  \
# 495               NaN   134.512115               NaN               NaN
# 1419    -5.267000e-05   136.379520           0.00362          -0.00362
# 9205              NaN   336.791754               NaN               NaN
# 5517    -8.517000e-04   320.728620           0.00218          -0.00218
# 8137    -2.200000e-08   131.946514           0.00003          -0.00003
#
#       koi_impact  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 495          NaN  ...             NaN        NaN             NaN
# 1419       0.663  ...             NaN      4.531           0.068
# 9205       0.093  ...          -163.0      3.956           0.315
# 5517       0.244  ...          -181.0      4.476           0.055
# 8137       0.799  ...          -314.0      3.964           0.228
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 495              NaN       NaN            NaN            NaN  298.21188
# 1419          -0.023     0.773          0.036         -0.053  296.54752
# 9205          -0.126     1.719          0.372         -0.558  295.53885
# 5517          -0.165     1.012          0.252         -0.108  287.47763
# 8137          -0.152     2.274          0.540         -0.720  293.77014
#
#             dec  koi_kepmag
# 495   44.324638      12.647
# 1419  44.941929      13.395
# 9205  40.409279      13.435
# 5517  46.141178      15.273
# 8137  46.236580      12.216
#
# [5 rows x 39 columns]

# %% [markdown]
# ### Correlation Analysis and Feature Selection

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_corr = X_train.copy()
df_corr['target'] = y_train.values

corr = df_corr.corr()

plt.figure(figsize=(12, 10))
sns.heatmap(corr, cmap="coolwarm", center=0, annot=False)
plt.title("Matriz de Correlação (incluindo target)")
plt.show()

# %%
target_corr = corr['target'].sort_values(ascending=False)
target_corr
# Out:
# target                               1.000000
# koi_steff_err2                       0.316581
# koi_tce_plnt_num                     0.214535
# koi_slogg_err2                       0.186685
# koi_slogg                            0.149002
# dec                                  0.108396
# koi_srad_err2                        0.089754
# koi_duration_err2                    0.083674
# koi_period_err2                      0.077759
# koi_insol_err2                       0.067922
# koi_kepmag                           0.056317
# koi_tce_delivname_q1_q17_dr25_tce    0.029266
# koi_time0bk_err2                     0.023838
# koi_depth_err2                       0.022194
# koi_prad_err2                        0.017819
# koi_period                           0.010076
# koi_time0bk                          0.006464
# koi_tce_delivname_q1_q16_tce         0.001938
# koi_impact_err2                     -0.002073
# koi_prad_err1                       -0.016815
# koi_prad                            -0.018781
# koi_depth_err1                      -0.022194
# koi_time0bk_err1                    -0.023838
# koi_tce_delivname_q1_q17_dr24_tce   -0.051918
# koi_insol                           -0.059924
# koi_impact                          -0.065888
# koi_srad                            -0.073643
# koi_insol_err1                      -0.073902
# koi_period_err1                     -0.077759
# koi_duration_err1                   -0.083674
# koi_impact_err1                     -0.113542
# koi_srad_err1                       -0.126626
# koi_slogg_err1                      -0.141291
# ra                                  -0.148297
# koi_duration                        -0.152631
# koi_steff                           -0.180901
# koi_model_snr                       -0.253627
# koi_depth                           -0.277115
# koi_teq                             -0.305154
# koi_steff_err1                      -0.344318
# Name: target, dtype: float64

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
feature_importances = pd.Series(model.feature_importances_, index=X_train.columns)
feature_importances.sort_values(ascending=False)
# Out:
# koi_prad                             0.096027
# koi_prad_err1                        0.053598
# koi_steff_err1                       0.052034
# koi_prad_err2                        0.048150
# koi_period                           0.046604
# koi_steff_err2                       0.040642
# koi_duration_err1                    0.034895
# koi_insol                            0.032901
# koi_duration_err2                    0.032227
# koi_impact                           0.031562
# koi_duration                         0.030190
# koi_insol_err1                       0.029951
# koi_teq                              0.029692
# koi_depth                            0.029451
# koi_insol_err2                       0.028814
# koi_period_err1                      0.027941
# koi_model_snr                        0.027192
# koi_period_err2                      0.024161
# koi_time0bk                          0.021527
# dec                                  0.021427
# koi_time0bk_err1                     0.020835
# ra                                   0.020456
# koi_time0bk_err2                     0.019485
# koi_slogg_err2                       0.017082
# koi_kepmag                           0.017055
# koi_srad_err1                        0.017027
# koi_impact_err1                      0.016672
# koi_depth_err1                       0.015117
# koi_steff                            0.014817
# koi_depth_err2                       0.014541
# koi_slogg                            0.014509
# koi_impact_err2                      0.014481
# koi_slogg_err1                       0.013554
# koi_srad                             0.013315
# koi_srad_err2                        0.012525
# koi_tce_plnt_num                     0.010500
# koi_tce_delivname_q1_q17_dr25_tce    0.004134
# koi_tce_delivname_q1_q16_tce         0.003283
# koi_tce_delivname_q1_q17_dr24_tce    0.001625
# dtype: float64

# %%
X_train = X_train.drop(columns=["koi_impact", "koi_duration", "koi_srad_err1", "koi_time0bk_err1", "koi_tce_plnt_num",
                                "koi_time0bk", "koi_depth_err1", "koi_slogg_err2", "koi_impact_err1", "ra", "dec",
                                "koi_depth_err2", "koi_kepmag", "koi_srad_err2", "koi_srad", "koi_slogg", "koi_impact_err2", 
                                "koi_steff", "koi_slogg_err1", "koi_tce_delivname_q1_q17_dr25_tce"])

# %%
X_test = X_test.drop(columns=["koi_impact", "koi_duration", "koi_srad_err1", "koi_time0bk_err1", "koi_tce_plnt_num",
                              "koi_time0bk", "koi_depth_err1", "koi_slogg_err2", "koi_impact_err1", "ra", "dec",
                                "koi_depth_err2", "koi_kepmag", "koi_srad_err2", "koi_srad", "koi_slogg", "koi_impact_err2", 
                                "koi_steff", "koi_slogg_err1", "koi_tce_delivname_q1_q17_dr25_tce"])

# %% [markdown]
# ## Model Training and Evaluation

# %%
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %% [markdown]
# ### XGBoost

# %%
XGBoostModel = XGBClassifier(random_state=42)

XGBoostModel.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
XGBoostPredictions = XGBoostModel.predict(X_test)

# %%
accuracy = accuracy_score(y_test, XGBoostPredictions)
report = classification_report(y_test, XGBoostPredictions)
confusion = confusion_matrix(y_test, XGBoostPredictions)

print("Accuracy:\n", accuracy)
print("Confusion Matrix:\n", confusion)
print("Relatory:\n", report)
# Out:
# Accuracy:
#  0.8480836236933798
# Confusion Matrix:
#  [[1248  207]
#  [ 229 1186]]
# Relatory:
#                precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85      1455
#            1       0.85      0.84      0.84      1415
#
#     accuracy                           0.85      2870
#    macro avg       0.85      0.85      0.85      2870
# weighted avg       0.85      0.85      0.85      2870

# %% [markdown]
# ### RandomForest Training

# %%
RandomForestModel = RandomForestClassifier(random_state=42)

RandomForestModel.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
RandomForestPredictions = RandomForestModel.predict(X_test)

# %%
accuracy = accuracy_score(y_test, RandomForestPredictions)
report = classification_report(y_test, RandomForestPredictions)
confusion = confusion_matrix(y_test, RandomForestPredictions)

print("Accuracy:\n", accuracy)
print("Confusion Matrix:\n", confusion)
print("Relatory:\n", report)
# Out:
# Accuracy:
#  0.8442508710801394
# Confusion Matrix:
#  [[1259  196]
#  [ 251 1164]]
# Relatory:
#                precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85      1455
#            1       0.86      0.82      0.84      1415
#
#     accuracy                           0.84      2870
#    macro avg       0.84      0.84      0.84      2870
# weighted avg       0.84      0.84      0.84      2870

# %% [markdown]
# ### LightGBM Training

# %%
LightGBMModel = LGBMClassifier(objective='binary', random_state=42, verbose=-1)

LightGBMModel.fit(X_train, y_train)
# Out:
# LGBMClassifier(objective='binary', random_state=42, verbose=-1)

# %%
LightGBMPredictions = LightGBMModel.predict(X_test)

# %%
accuracy = accuracy_score(y_test, LightGBMPredictions)
report = classification_report(y_test, LightGBMPredictions)
confusion = confusion_matrix(y_test, LightGBMPredictions)

print("Accuracy:\n", accuracy)
print("Confusion Matrix:\n", confusion)
print("Relatory:\n", report)
# Out:
# Accuracy:
#  0.854006968641115
# Confusion Matrix:
#  [[1256  199]
#  [ 220 1195]]
# Relatory:
#                precision    recall  f1-score   support
#
#            0       0.85      0.86      0.86      1455
#            1       0.86      0.84      0.85      1415
#
#     accuracy                           0.85      2870
#    macro avg       0.85      0.85      0.85      2870
# weighted avg       0.85      0.85      0.85      2870

# %% [markdown]
# ### Decision Tree

# %%
DecisionTreeModel = DecisionTreeClassifier(random_state=42)

DecisionTreeModel.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
DecisionTreePredictions = DecisionTreeModel.predict(X_test)

# %%
accuracy = accuracy_score(y_test, DecisionTreePredictions)
report = classification_report(y_test, DecisionTreePredictions)
confusion = confusion_matrix(y_test, DecisionTreePredictions)

print("Accuracy:\n", accuracy)
print("Confusion Matrix:\n", confusion)
print("Relatory:\n", report)
# Out:
# Accuracy:
#  0.8013937282229965
# Confusion Matrix:
#  [[1170  285]
#  [ 285 1130]]
# Relatory:
#                precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80      1455
#            1       0.80      0.80      0.80      1415
#
#     accuracy                           0.80      2870
#    macro avg       0.80      0.80      0.80      2870
# weighted avg       0.80      0.80      0.80      2870
